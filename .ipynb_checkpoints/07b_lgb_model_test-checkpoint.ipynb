# %%
GPU = False  #set to True to use GPU for LightGBM 
OPTUNA = False #set to True to run Optuna first, false to use saved hyperparameters

# %% [markdown]
# ## LightGBM Model Testing

# %%
import os

import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 500)

from sklearn.metrics import (
    accuracy_score,
    roc_auc_score,
    roc_curve,
    confusion_matrix,
    classification_report,
)

from sklearn.model_selection import (
    StratifiedKFold, 
    TimeSeriesSplit,
)

import lightgbm as lgb
from lightgbm import (
    early_stopping,
    log_evaluation,
)
print('LGB version:', lgb.__version__)

import optuna
from optuna.visualization import plot_optimization_history, plot_param_importances

import neptune.new as neptune
from neptune.new.integrations.lightgbm import (
    NeptuneCallback, 
    create_booster_summary,
)
import neptune.new.integrations.optuna as optuna_utils
from neptune.new.types import File

from tqdm import tqdm

import shap

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from src.common_functions import plot_confusion_matrix

from pathlib import Path  #for Windows/Linux compatibility
DATAPATH = Path(r'data')

import ipynbname

import warnings
warnings.simplefilter('ignore')
# Out:
# LGB version: 3.3.3

# %%
TRAIN_NAME = "train_selected.csv"
TEST_NAME = "test_selected.csv"

train = pd.read_csv(DATAPATH / TRAIN_NAME)
test = pd.read_csv(DATAPATH / TEST_NAME)

# %% [markdown]
# **Setup Neptuna.ai experiment tracking**

# %%
try:
    #NEPTUNE_API_TOKEN = os.environ['NEPTUNE_API_TOKEN']
    NEPTUNE_API_TOKEN = "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxZDgwMzIwMC1jZjNiLTQ2MGEtYTFjNy1jZGI2ZDQyZTIwYTUifQ=="
except:
    raise Exception('Set environment variable NEPTUNE_API_TOKEN')
    
PROJECT = "cmunch1/nba-prediction"
PROJECT_OPTUNA = "cmunch1/nba-optuna" #for 2nd run if hyperparameters are tuned
SOURCE = ipynbname.name()
SOURCE_SPLIT = "03_train_test_split.ipynb"
SOURCE_ENG = "05_feature_engineering.ipynb"
SOURCE_SEL = "06_feature_selection.ipynb"
    
run = neptune.init(
    project=PROJECT,
    source_files=[SOURCE,SOURCE_SPLIT,SOURCE_ENG,SOURCE_SEL],
    api_token=NEPTUNE_API_TOKEN,
)
neptune_callback = NeptuneCallback(run=run)
# Out:
# https://app.neptune.ai/cmunch1/nba-prediction/e/XGB-37
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.

# %% [markdown]
# **Logging Note**

# %%
run["note"] = "Test"
run["sys/tags"].add(["lightgbm",])
run['dataset/train'] = TRAIN_NAME
run['dataset/test'] = TEST_NAME

# %% [markdown]
# **Options**

# %%
run["model/parameters/GPU"] = GPU
run["model/parameters/OPTUNA"] = OPTUNA

if OPTUNA:
    run["model/optuna/optuna_cv"] = OPTUNA_CV = "TimeSeriesSplit"
    #run["model/parameters/optuna_cv"] = OPTUNA_CV = "StratifiedKFold"    
    run["model/optuna/optuna_folds"] = OPTUNA_FOLDS = 5
    run["model/optuna/optuna_trials"] = OPTUNA_TRIALS = 50

run["model/parameters/k_folds"] = K_FOLDS = 5
run["model/parameters/seed"] = SEED = 13
#run["model/parameters/num_boost_round"] = NUM_BOOST_ROUND = 700
#run["model/parameters/enable_categorical"] = ENABLE_CATEGORICAL = True
run["model/parameters/early_stopping"] = EARLY_STOPPING = 200 

LOG_EVALUATION = 100
VERBOSITY = 0

STATIC_PARAMS = {
                'seed': SEED,
                'verbosity': -1,           
                'boosting_type': 'gbdt',
                'objective': 'binary',
                'metric': 'auc', 
                }

GPU_PARAMS = {
            'device': 'gpu',
            'gpu_platform_id': 0,
            'gpu_device_id': 0,
             }

if GPU:
    STATIC_PARAMS = STATIC_PARAMS | GPU_PARAMS

# %% [markdown]
# **Fix Datatypes for smaller memory footprint**

# %%
def fix_datatypes(df):
    df['GAME_DATE_EST'] = pd.to_datetime(df['GAME_DATE_EST'])

    long_integer_fields = ['GAME_ID', 'HOME_TEAM_ID', 'VISITOR_TEAM_ID', 'SEASON']

    #convert long integer fields to int32 from int64
    for field in long_integer_fields:
        df[field] = df[field].astype('int32')
    
    #convert the remaining int64s to int8
    for field in df.select_dtypes(include=['int64']).columns.tolist():
        df[field] = df[field].astype('int8')
        
    #convert float64s to float16s
    for field in df.select_dtypes(include=['float64']).columns.tolist():
        df[field] = df[field].astype('float16')
        
    return df

train = fix_datatypes(train)
test = fix_datatypes(test)

# %% [markdown]
# **Encode categoricals**

# %%
# To use special category feature capabalities in XGB and LGB, categoricals must be ints from 0 to N-1
# Conversion can be accomplished by simple subtraction for several features
# (these capabilities may or may not be used, but encoding does not hurt anything)

def encode_categoricals(df):
    first_team_ID = df['HOME_TEAM_ID'].min()
    first_season = df['SEASON'].min()
    
    df['HOME_TEAM_ID'] = (df['HOME_TEAM_ID'] - first_team_ID).astype('int8')
    df['VISITOR_TEAM_ID'] = (df['VISITOR_TEAM_ID'] - first_team_ID).astype('int8')
    df['SEASON'] = (df['SEASON'] - first_season).astype('int8')
    
    return df

train = encode_categoricals(train)
test = encode_categoricals(test)

# %% [markdown]
# **Select Features**

# %%
target = train['TARGET']
test_target = test['TARGET']

category_columns = ['HOME_TEAM_ID', 'VISITOR_TEAM_ID', 'SEASON', 'HOME_TEAM_WINS', 'PLAYOFF', 'CONFERENCE_x', 'CONFERENCE_y',]
#for field in category_columns:
#    train[field] = train[field].astype('category')
#    test[field] = test[field].astype('category')

all_columns = train.columns.tolist()
drop_columns = ['TARGET', 'GAME_DATE_EST', 'GAME_ID', ] 


use_columns = [item for item in all_columns if item not in drop_columns]

train = train[use_columns]
test = test[use_columns]


run["model/features"].log(use_columns)

# %% [markdown]
# ### Optuna Hyperparameter Tuning

# %%
def objective(trial):

    train_oof = np.zeros((train.shape[0],))
    
    
    lgb_params= {
                "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
                "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
                "learning_rate": trial.suggest_loguniform('learning_rate', 1e-4, 0.5),
                "max_depth": trial.suggest_categorical('max_depth', [5,10,20,40,100, -1]),
                "n_estimators": trial.suggest_int("n_estimators", 50, 200000),
                "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
                "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
                "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
                "num_leaves": trial.suggest_int("num_leaves", 2, 1000),
                "min_child_samples": trial.suggest_int("min_child_samples", 5, 300),
                "cat_smooth" : trial.suggest_int('min_data_per_groups', 1, 100)
                }

    lgb_params = lgb_params | STATIC_PARAMS
        
    #pruning_callback = optuna.integration.LightGBMPruningCallback(trial, "auc")
    
    if OPTUNA_CV == "StratifiedKFold": 
        kf = StratifiedKFold(n_splits=OPTUNA_FOLDS, shuffle=True, random_state=SEED)
    elif OPTUNA_CV == "TimeSeriesSplit":
        kf = TimeSeriesSplit(n_splits=OPTUNA_FOLDS)
    

    for f, (train_ind, val_ind) in (enumerate(kf.split(train, target))):

        train_df, val_df = train.iloc[train_ind], train.iloc[val_ind]
        
        train_target, val_target = target[train_ind], target[val_ind]

        train_lgbdataset = lgb.Dataset(train_df, label=train_target,categorical_feature=category_columns)
        val_lgbdataset = lgb.Dataset(val_df, label=val_target, reference = train_lgbdataset, categorical_feature=category_columns)


        model =  lgb.train(lgb_params, 
                           train_lgbdataset,
                           valid_sets=val_lgbdataset,
                           #num_boost_round = NUM_BOOST_ROUND,
                           callbacks=[#log_evaluation(LOG_EVALUATION),
                                      early_stopping(EARLY_STOPPING,verbose=False),
                                      #pruning_callback,
                                    ]               
                           #verbose_eval= VERBOSE_EVAL,
                          )

        temp_oof = model.predict(val_df)

        train_oof[val_ind] = temp_oof

        #print(roc_auc_score(val_target, temp_oof))
    
    val_score = roc_auc_score(target, train_oof)
    
    return val_score

# %%
def run_optuna():
    
     #log separate Neptune run for optuna hyperameter tuning
    run2 = neptune.init(
                    project=PROJECT_OPTUNA,
                    source_files=[SOURCE,SOURCE_SPLIT,SOURCE_ENG,SOURCE_SEL],
                    api_token=NEPTUNE_API_TOKEN,
                    )
    run2["options/optuna_cv"] = OPTUNA_CV 
    run2["options/optuna_folds"] = OPTUNA_FOLDS 
    run2["options/optuna_trials"] = OPTUNA_TRIALS 
    run2["options/GPU"] = GPU
    #run2["options/enable_categorical"] = ENABLE_CATEGORICAL
    run2["features"].log(use_columns)
    run2["sys/tags"].add(["lightgbm",])
    

    study = optuna.create_study(direction='maximize')
    study.optimize(objective, n_trials = OPTUNA_TRIALS,)

    optuna_utils.log_study_metadata(study, run2)
    
    print("Study Best Value:",study.best_value)
    print("Study Best Params:",study.best_params)
    
    plot_optimization_history(study)
    
    plot_param_importances(study)
    
    run2["best_value"] = study.best_value
    run2["best_params"] = study.best_params
    run2["static_params"] = STATIC_PARAMS
    
    run2.stop()
    
    return study.best_params

# %% [markdown]
# **Set Hyperparameters**

# %%
if OPTUNA:
    tuned_params = run_optuna()
else:
    tuned_params = {
                #current best hyperparameters from previous tuning:     
                'lambda_l1': 1.795338637297326e-08, 
                'lambda_l2': 0.004705909102689521, 
                'learning_rate': 0.0514056673966814, 
                'max_depth': 100, 
                'n_estimators': 136307, 
                'feature_fraction': 0.707667657054092, 
                'bagging_fraction': 0.5528109129804049, 
                'bagging_freq': 1, 
                'num_leaves': 316, 
                'min_child_samples': 300, 
                'min_data_per_groups': 88,
                }

lgb_params= STATIC_PARAMS | tuned_params   

run["model/params"] = lgb_params
# Out:
# https://app.neptune.ai/cmunch1/nba-optuna/e/NBAOPT-2
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# [I 2022-10-26 20:17:31,252] A new study created in memory with name: no-name-07b37aa0-1c5d-4775-b24e-e49e0994df39
# [I 2022-10-26 20:17:45,678] Trial 0 finished with value: 0.5864109750548132 and parameters: {'lambda_l1': 2.057113334388365e-06, 'lambda_l2': 5.866945150696147e-06, 'learning_rate': 0.23122991106011354, 'max_depth': 40, 'n_estimators': 47497, 'feature_fraction': 0.7946397742418183, 'bagging_fraction': 0.8386376892126597, 'bagging_freq': 2, 'num_leaves': 582, 'min_child_samples': 297, 'min_data_per_groups': 63}. Best is trial 0 with value: 0.5864109750548132.
# [I 2022-10-26 20:17:51,794] Trial 1 finished with value: 0.5792836963806458 and parameters: {'lambda_l1': 0.26938780841538507, 'lambda_l2': 0.022469857777449136, 'learning_rate': 0.2007476829593076, 'max_depth': 5, 'n_estimators': 149740, 'feature_fraction': 0.9508812889066973, 'bagging_fraction': 0.9582215049838403, 'bagging_freq': 2, 'num_leaves': 351, 'min_child_samples': 87, 'min_data_per_groups': 10}. Best is trial 0 with value: 0.5864109750548132.
# [I 2022-10-26 20:18:27,320] Trial 2 finished with value: 0.5796522376504357 and parameters: {'lambda_l1': 0.0010124911665302292, 'lambda_l2': 3.245402634292397e-06, 'learning_rate': 0.0016103010279371374, 'max_depth': 100, 'n_estimators': 6224, 'feature_fraction': 0.9725701585964207, 'bagging_fraction': 0.7051502878564038, 'bagging_freq': 2, 'num_leaves': 78, 'min_child_samples': 55, 'min_data_per_groups': 58}. Best is trial 0 with value: 0.5864109750548132.
# [I 2022-10-26 20:18:58,032] Trial 3 finished with value: 0.5818925110529622 and parameters: {'lambda_l1': 0.0006291873994232375, 'lambda_l2': 1.2639774813029033e-08, 'learning_rate': 0.0014129753835290429, 'max_depth': 10, 'n_estimators': 128716, 'feature_fraction': 0.738257906144743, 'bagging_fraction': 0.779164995272329, 'bagging_freq': 6, 'num_leaves': 358, 'min_child_samples': 104, 'min_data_per_groups': 57}. Best is trial 0 with value: 0.5864109750548132.
# [I 2022-10-26 20:19:05,685] Trial 4 finished with value: 0.5842673762700603 and parameters: {'lambda_l1': 1.4656021340266514e-08, 'lambda_l2': 8.980146307486016e-07, 'learning_rate': 0.005143452967231714, 'max_depth': 5, 'n_estimators': 163997, 'feature_fraction': 0.4024034925107792, 'bagging_fraction': 0.8294100968538329, 'bagging_freq': 5, 'num_leaves': 122, 'min_child_samples': 19, 'min_data_per_groups': 6}. Best is trial 0 with value: 0.5864109750548132.
# [I 2022-10-26 20:19:55,663] Trial 5 finished with value: 0.587475928449146 and parameters: {'lambda_l1': 1.3096903495683466e-06, 'lambda_l2': 0.0007370194633981408, 'learning_rate': 0.001228818582380529, 'max_depth': 100, 'n_estimators': 14498, 'feature_fraction': 0.48290440620558267, 'bagging_fraction': 0.8444803503534863, 'bagging_freq': 1, 'num_leaves': 995, 'min_child_samples': 40, 'min_data_per_groups': 47}. Best is trial 5 with value: 0.587475928449146.
# [I 2022-10-26 20:20:06,777] Trial 6 finished with value: 0.5802819641774017 and parameters: {'lambda_l1': 8.616262435369502e-06, 'lambda_l2': 3.329317217777822, 'learning_rate': 0.000746443321534266, 'max_depth': -1, 'n_estimators': 76426, 'feature_fraction': 0.7245320757683451, 'bagging_fraction': 0.43562685887970537, 'bagging_freq': 2, 'num_leaves': 186, 'min_child_samples': 135, 'min_data_per_groups': 18}. Best is trial 5 with value: 0.587475928449146.
# [I 2022-10-26 20:20:17,809] Trial 7 finished with value: 0.5583100074132545 and parameters: {'lambda_l1': 0.28851507697541795, 'lambda_l2': 2.456847537178349, 'learning_rate': 0.000266689881765252, 'max_depth': -1, 'n_estimators': 75186, 'feature_fraction': 0.6328100710637721, 'bagging_fraction': 0.7158599818711895, 'bagging_freq': 4, 'num_leaves': 641, 'min_child_samples': 211, 'min_data_per_groups': 21}. Best is trial 5 with value: 0.587475928449146.
# [I 2022-10-26 20:20:34,897] Trial 8 finished with value: 0.570009792721508 and parameters: {'lambda_l1': 0.07527142497929251, 'lambda_l2': 2.7308818586540175e-06, 'learning_rate': 0.00012038532917506891, 'max_depth': -1, 'n_estimators': 84214, 'feature_fraction': 0.4186539052831695, 'bagging_fraction': 0.49412951552303874, 'bagging_freq': 3, 'num_leaves': 927, 'min_child_samples': 134, 'min_data_per_groups': 20}. Best is trial 5 with value: 0.587475928449146.
# [I 2022-10-26 20:20:46,721] Trial 9 finished with value: 0.5881996543704977 and parameters: {'lambda_l1': 0.001969805684609624, 'lambda_l2': 0.05277880045130658, 'learning_rate': 0.01584815727805506, 'max_depth': 100, 'n_estimators': 114753, 'feature_fraction': 0.853282530354198, 'bagging_fraction': 0.4394773469607823, 'bagging_freq': 7, 'num_leaves': 696, 'min_child_samples': 81, 'min_data_per_groups': 38}. Best is trial 9 with value: 0.5881996543704977.
# [I 2022-10-26 20:20:53,428] Trial 10 finished with value: 0.5926885076271788 and parameters: {'lambda_l1': 3.37855292006834, 'lambda_l2': 0.008954885950764555, 'learning_rate': 0.03802706724626445, 'max_depth': 20, 'n_estimators': 120899, 'feature_fraction': 0.8560536111781186, 'bagging_fraction': 0.5895281405575908, 'bagging_freq': 7, 'num_leaves': 770, 'min_child_samples': 201, 'min_data_per_groups': 92}. Best is trial 10 with value: 0.5926885076271788.
# [I 2022-10-26 20:20:59,794] Trial 11 finished with value: 0.5933739653749035 and parameters: {'lambda_l1': 4.4143677220431385, 'lambda_l2': 0.02335315547728647, 'learning_rate': 0.036229123384380606, 'max_depth': 20, 'n_estimators': 199824, 'feature_fraction': 0.8602396731556362, 'bagging_fraction': 0.5646239732036732, 'bagging_freq': 7, 'num_leaves': 760, 'min_child_samples': 204, 'min_data_per_groups': 90}. Best is trial 11 with value: 0.5933739653749035.
# [I 2022-10-26 20:21:05,925] Trial 12 finished with value: 0.5907198005964922 and parameters: {'lambda_l1': 7.353107928497858, 'lambda_l2': 0.004696561469612828, 'learning_rate': 0.03719204738995726, 'max_depth': 20, 'n_estimators': 180845, 'feature_fraction': 0.8953751121686689, 'bagging_fraction': 0.5732768787475662, 'bagging_freq': 7, 'num_leaves': 812, 'min_child_samples': 209, 'min_data_per_groups': 99}. Best is trial 11 with value: 0.5933739653749035.
# [I 2022-10-26 20:21:15,575] Trial 13 finished with value: 0.5944113085919939 and parameters: {'lambda_l1': 7.703731089772769, 'lambda_l2': 0.22270345158395194, 'learning_rate': 0.04014400429932344, 'max_depth': 20, 'n_estimators': 189937, 'feature_fraction': 0.8488146746046608, 'bagging_fraction': 0.6049828755227592, 'bagging_freq': 6, 'num_leaves': 789, 'min_child_samples': 214, 'min_data_per_groups': 98}. Best is trial 13 with value: 0.5944113085919939.
# [I 2022-10-26 20:21:22,724] Trial 14 finished with value: 0.5931556304888487 and parameters: {'lambda_l1': 0.019666630067682114, 'lambda_l2': 0.3041153083271185, 'learning_rate': 0.07445371583010069, 'max_depth': 20, 'n_estimators': 198354, 'feature_fraction': 0.6276378320573505, 'bagging_fraction': 0.582646732719644, 'bagging_freq': 5, 'num_leaves': 878, 'min_child_samples': 265, 'min_data_per_groups': 80}. Best is trial 13 with value: 0.5944113085919939.
# [I 2022-10-26 20:21:35,407] Trial 15 finished with value: 0.5907449929333546 and parameters: {'lambda_l1': 8.08067005901459, 'lambda_l2': 0.00012735558612672498, 'learning_rate': 0.00791194086510272, 'max_depth': 20, 'n_estimators': 198800, 'feature_fraction': 0.7884396767958458, 'bagging_fraction': 0.6305554615361177, 'bagging_freq': 6, 'num_leaves': 538, 'min_child_samples': 175, 'min_data_per_groups': 78}. Best is trial 13 with value: 0.5944113085919939.
# [I 2022-10-26 20:21:40,706] Trial 16 finished with value: 0.5826118692626597 and parameters: {'lambda_l1': 0.7564278741620168, 'lambda_l2': 0.2544826167993689, 'learning_rate': 0.4441082357474401, 'max_depth': 20, 'n_estimators': 157099, 'feature_fraction': 0.6326612582076008, 'bagging_fraction': 0.5080378614748755, 'bagging_freq': 6, 'num_leaves': 436, 'min_child_samples': 249, 'min_data_per_groups': 78}. Best is trial 13 with value: 0.5944113085919939.
# [I 2022-10-26 20:21:50,306] Trial 17 finished with value: 0.5886703961932522 and parameters: {'lambda_l1': 0.01156263879661674, 'lambda_l2': 0.0003432162721204564, 'learning_rate': 0.06855774333941163, 'max_depth': 40, 'n_estimators': 176663, 'feature_fraction': 0.9985286683023822, 'bagging_fraction': 0.6486825891271508, 'bagging_freq': 5, 'num_leaves': 772, 'min_child_samples': 168, 'min_data_per_groups': 89}. Best is trial 13 with value: 0.5944113085919939.
# [I 2022-10-26 20:21:58,918] Trial 18 finished with value: 0.5929667776564594 and parameters: {'lambda_l1': 8.206328547294348e-05, 'lambda_l2': 0.3854447940787621, 'learning_rate': 0.013426648975539223, 'max_depth': 10, 'n_estimators': 140874, 'feature_fraction': 0.9066470110300114, 'bagging_fraction': 0.5029291419015538, 'bagging_freq': 4, 'num_leaves': 664, 'min_child_samples': 242, 'min_data_per_groups': 100}. Best is trial 13 with value: 0.5944113085919939.
# [I 2022-10-26 20:22:08,281] Trial 19 finished with value: 0.5896206503597528 and parameters: {'lambda_l1': 1.1874415281790713, 'lambda_l2': 0.0023002591890753606, 'learning_rate': 0.11244201919550095, 'max_depth': 20, 'n_estimators': 178564, 'feature_fraction': 0.8051074426861212, 'bagging_fraction': 0.6601828956480388, 'bagging_freq': 6, 'num_leaves': 872, 'min_child_samples': 281, 'min_data_per_groups': 69}. Best is trial 13 with value: 0.5944113085919939.
# [I 2022-10-26 20:22:19,129] Trial 20 finished with value: 0.580284007642497 and parameters: {'lambda_l1': 0.0170172961004418, 'lambda_l2': 7.622076105716447, 'learning_rate': 0.0036599790850358805, 'max_depth': 20, 'n_estimators': 197593, 'feature_fraction': 0.567149015756068, 'bagging_fraction': 0.7614396978782307, 'bagging_freq': 7, 'num_leaves': 990, 'min_child_samples': 231, 'min_data_per_groups': 38}. Best is trial 13 with value: 0.5944113085919939.
# [I 2022-10-26 20:22:25,173] Trial 21 finished with value: 0.5946931039885381 and parameters: {'lambda_l1': 0.049412134418485944, 'lambda_l2': 0.20343820562447645, 'learning_rate': 0.03457877659847137, 'max_depth': 20, 'n_estimators': 194270, 'feature_fraction': 0.5971758488348358, 'bagging_fraction': 0.5851565639368758, 'bagging_freq': 5, 'num_leaves': 833, 'min_child_samples': 265, 'min_data_per_groups': 82}. Best is trial 21 with value: 0.5946931039885381.
# [I 2022-10-26 20:22:32,107] Trial 22 finished with value: 0.5955296806597541 and parameters: {'lambda_l1': 0.09068447762736183, 'lambda_l2': 0.07827969599493464, 'learning_rate': 0.022430098022995466, 'max_depth': 20, 'n_estimators': 171605, 'feature_fraction': 0.5353829664088148, 'bagging_fraction': 0.5409430269595917, 'bagging_freq': 5, 'num_leaves': 733, 'min_child_samples': 191, 'min_data_per_groups': 88}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:22:40,800] Trial 23 finished with value: 0.595048744909978 and parameters: {'lambda_l1': 0.08495568545042413, 'lambda_l2': 0.10991239246356212, 'learning_rate': 0.017858749680069848, 'max_depth': 20, 'n_estimators': 168966, 'feature_fraction': 0.5389098144225575, 'bagging_fraction': 0.5373608161420069, 'bagging_freq': 4, 'num_leaves': 852, 'min_child_samples': 176, 'min_data_per_groups': 82}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:22:50,890] Trial 24 finished with value: 0.5927027104895399 and parameters: {'lambda_l1': 0.08632394399944482, 'lambda_l2': 5.0785319289108664e-05, 'learning_rate': 0.012987019349309082, 'max_depth': 20, 'n_estimators': 163590, 'feature_fraction': 0.5333593701800512, 'bagging_fraction': 0.530603982549064, 'bagging_freq': 4, 'num_leaves': 903, 'min_child_samples': 176, 'min_data_per_groups': 72}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:22:56,681] Trial 25 finished with value: 0.5935981576742659 and parameters: {'lambda_l1': 0.003557625971379585, 'lambda_l2': 1.364025786819629, 'learning_rate': 0.025522950237475552, 'max_depth': 20, 'n_estimators': 138700, 'feature_fraction': 0.5595025634684162, 'bagging_fraction': 0.4051326079893346, 'bagging_freq': 3, 'num_leaves': 703, 'min_child_samples': 152, 'min_data_per_groups': 85}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:23:14,401] Trial 26 finished with value: 0.5908260256837669 and parameters: {'lambda_l1': 0.00013940911486627234, 'lambda_l2': 0.05041693522187576, 'learning_rate': 0.003399120934493975, 'max_depth': 10, 'n_estimators': 107103, 'feature_fraction': 0.4834189994139609, 'bagging_fraction': 0.5367165747049063, 'bagging_freq': 5, 'num_leaves': 584, 'min_child_samples': 130, 'min_data_per_groups': 70}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:23:20,305] Trial 27 finished with value: 0.5911758325903543 and parameters: {'lambda_l1': 0.0575281280883324, 'lambda_l2': 0.0014834314855176258, 'learning_rate': 0.007772750241269627, 'max_depth': 40, 'n_estimators': 173216, 'feature_fraction': 0.52115603239733, 'bagging_fraction': 0.4697585919026438, 'bagging_freq': 4, 'num_leaves': 853, 'min_child_samples': 259, 'min_data_per_groups': 83}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:23:26,919] Trial 28 finished with value: 0.5887914325027256 and parameters: {'lambda_l1': 0.004154039699512933, 'lambda_l2': 0.09370826061799928, 'learning_rate': 0.09089541692251465, 'max_depth': 5, 'n_estimators': 143432, 'feature_fraction': 0.6834936997618558, 'bagging_fraction': 0.6702455090913144, 'bagging_freq': 3, 'num_leaves': 467, 'min_child_samples': 186, 'min_data_per_groups': 46}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:23:31,200] Trial 29 finished with value: 0.5898298676477296 and parameters: {'lambda_l1': 0.30150179740900085, 'lambda_l2': 0.7135327812790361, 'learning_rate': 0.17593212824397644, 'max_depth': 40, 'n_estimators': 92008, 'feature_fraction': 0.5905649450323213, 'bagging_fraction': 0.5457063400381987, 'bagging_freq': 5, 'num_leaves': 600, 'min_child_samples': 298, 'min_data_per_groups': 60}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:23:37,125] Trial 30 finished with value: 0.5935906233716625 and parameters: {'lambda_l1': 2.6690643644871112e-05, 'lambda_l2': 0.006916328537098955, 'learning_rate': 0.017923042702923296, 'max_depth': 20, 'n_estimators': 167453, 'feature_fraction': 0.45068765159328944, 'bagging_fraction': 0.4609631894859438, 'bagging_freq': 4, 'num_leaves': 944, 'min_child_samples': 281, 'min_data_per_groups': 67}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:23:44,460] Trial 31 finished with value: 0.5927840084224456 and parameters: {'lambda_l1': 0.9546855271894212, 'lambda_l2': 0.18235896781540226, 'learning_rate': 0.05975318637812006, 'max_depth': 20, 'n_estimators': 186660, 'feature_fraction': 0.6711437250256678, 'bagging_fraction': 0.5964263678030024, 'bagging_freq': 6, 'num_leaves': 811, 'min_child_samples': 225, 'min_data_per_groups': 95}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:23:51,350] Trial 32 finished with value: 0.595085355693022 and parameters: {'lambda_l1': 0.10948792886519187, 'lambda_l2': 9.689006555384237, 'learning_rate': 0.024660171287701843, 'max_depth': 20, 'n_estimators': 152339, 'feature_fraction': 0.6009668699787645, 'bagging_fraction': 0.6165338893221001, 'bagging_freq': 5, 'num_leaves': 732, 'min_child_samples': 228, 'min_data_per_groups': 84}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:24:01,185] Trial 33 finished with value: 0.5949765372769528 and parameters: {'lambda_l1': 0.02189341585819323, 'lambda_l2': 9.306870003116023, 'learning_rate': 0.025647702876863396, 'max_depth': 20, 'n_estimators': 150083, 'feature_fraction': 0.5998750917353168, 'bagging_fraction': 0.6272159478607533, 'bagging_freq': 5, 'num_leaves': 725, 'min_child_samples': 189, 'min_data_per_groups': 87}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:24:10,879] Trial 34 finished with value: 0.585718692757629 and parameters: {'lambda_l1': 0.01152503857075958, 'lambda_l2': 9.6216422882279, 'learning_rate': 0.009825747612216865, 'max_depth': 5, 'n_estimators': 127966, 'feature_fraction': 0.5120717563908678, 'bagging_fraction': 0.9569750950890399, 'bagging_freq': 4, 'num_leaves': 730, 'min_child_samples': 156, 'min_data_per_groups': 74}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:24:25,926] Trial 35 finished with value: 0.5900988835879428 and parameters: {'lambda_l1': 0.0005538520564474677, 'lambda_l2': 3.1565880469233116, 'learning_rate': 0.021727584335450256, 'max_depth': 20, 'n_estimators': 151329, 'feature_fraction': 0.551698792721899, 'bagging_fraction': 0.7021690153752125, 'bagging_freq': 5, 'num_leaves': 530, 'min_child_samples': 189, 'min_data_per_groups': 62}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:24:38,494] Trial 36 finished with value: 0.5906984222078421 and parameters: {'lambda_l1': 0.13907827730508404, 'lambda_l2': 0.9849448792212901, 'learning_rate': 0.004989392364162317, 'max_depth': 10, 'n_estimators': 154286, 'feature_fraction': 0.5979712161362934, 'bagging_fraction': 0.624694116161513, 'bagging_freq': 3, 'num_leaves': 654, 'min_child_samples': 152, 'min_data_per_groups': 87}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:24:45,677] Trial 37 finished with value: 0.590439471503146 and parameters: {'lambda_l1': 0.36035820774114147, 'lambda_l2': 2.4144181579786825e-05, 'learning_rate': 0.12792100249468663, 'max_depth': 100, 'n_estimators': 132044, 'feature_fraction': 0.48786572153299756, 'bagging_fraction': 0.7387997336994301, 'bagging_freq': 5, 'num_leaves': 326, 'min_child_samples': 227, 'min_data_per_groups': 53}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:25:10,559] Trial 38 finished with value: 0.5871778165297794 and parameters: {'lambda_l1': 4.954484029702526e-07, 'lambda_l2': 1.3690054318870976e-07, 'learning_rate': 0.002405021690157853, 'max_depth': 20, 'n_estimators': 161568, 'feature_fraction': 0.6580911408786966, 'bagging_fraction': 0.6785605498932759, 'bagging_freq': 4, 'num_leaves': 622, 'min_child_samples': 98, 'min_data_per_groups': 94}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:25:24,798] Trial 39 finished with value: 0.5875165169695893 and parameters: {'lambda_l1': 0.029046595917064308, 'lambda_l2': 4.558889322744461, 'learning_rate': 0.010881883369238616, 'max_depth': -1, 'n_estimators': 54530, 'feature_fraction': 0.7064370516982357, 'bagging_fraction': 0.6271160918413767, 'bagging_freq': 5, 'num_leaves': 723, 'min_child_samples': 128, 'min_data_per_groups': 66}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:25:28,419] Trial 40 finished with value: 0.583236697712985 and parameters: {'lambda_l1': 0.0012331948117483779, 'lambda_l2': 0.018387208271525717, 'learning_rate': 0.35874530541094246, 'max_depth': 5, 'n_estimators': 110035, 'feature_fraction': 0.4522035193398265, 'bagging_fraction': 0.8340271941934069, 'bagging_freq': 1, 'num_leaves': 381, 'min_child_samples': 193, 'min_data_per_groups': 75}. Best is trial 22 with value: 0.5955296806597541.
# [I 2022-10-26 20:25:34,157] Trial 41 finished with value: 0.5966480059306036 and parameters: {'lambda_l1': 0.005360547526748144, 'lambda_l2': 1.1110651532516205, 'learning_rate': 0.02491008620991838, 'max_depth': 20, 'n_estimators': 170190, 'feature_fraction': 0.5913968004295521, 'bagging_fraction': 0.5581590256707243, 'bagging_freq': 5, 'num_leaves': 848, 'min_child_samples': 273, 'min_data_per_groups': 83}. Best is trial 41 with value: 0.5966480059306036.
# [I 2022-10-26 20:25:39,430] Trial 42 finished with value: 0.5951799088508495 and parameters: {'lambda_l1': 0.1496213510592772, 'lambda_l2': 1.5152879024107861, 'learning_rate': 0.022139038757767435, 'max_depth': 20, 'n_estimators': 171281, 'feature_fraction': 0.5789254135334594, 'bagging_fraction': 0.5402781822746576, 'bagging_freq': 5, 'num_leaves': 931, 'min_child_samples': 283, 'min_data_per_groups': 84}. Best is trial 41 with value: 0.5966480059306036.
# [I 2022-10-26 20:25:51,103] Trial 43 finished with value: 0.5904521339672006 and parameters: {'lambda_l1': 0.005227234096220984, 'lambda_l2': 1.7995187179317573, 'learning_rate': 0.0052740105992094095, 'max_depth': 20, 'n_estimators': 171211, 'feature_fraction': 0.5745789893538183, 'bagging_fraction': 0.5456027617843315, 'bagging_freq': 6, 'num_leaves': 948, 'min_child_samples': 245, 'min_data_per_groups': 93}. Best is trial 41 with value: 0.5966480059306036.
# [I 2022-10-26 20:25:56,082] Trial 44 finished with value: 0.5954609476973393 and parameters: {'lambda_l1': 0.1764486701423011, 'lambda_l2': 0.060668794810731015, 'learning_rate': 0.05275853892723099, 'max_depth': 100, 'n_estimators': 183802, 'feature_fraction': 0.5320284360149613, 'bagging_fraction': 0.47038127715696854, 'bagging_freq': 4, 'num_leaves': 996, 'min_child_samples': 279, 'min_data_per_groups': 83}. Best is trial 41 with value: 0.5966480059306036.
# [I 2022-10-26 20:26:03,113] Trial 45 finished with value: 0.5939183148382583 and parameters: {'lambda_l1': 2.2844359740720894, 'lambda_l2': 0.6819046033936151, 'learning_rate': 0.059587226114188686, 'max_depth': 100, 'n_estimators': 184781, 'feature_fraction': 0.504952107316713, 'bagging_fraction': 0.4806774953251376, 'bagging_freq': 5, 'num_leaves': 982, 'min_child_samples': 282, 'min_data_per_groups': 77}. Best is trial 41 with value: 0.5966480059306036.
# [I 2022-10-26 20:26:09,121] Trial 46 finished with value: 0.5955043518319025 and parameters: {'lambda_l1': 0.21855849556546433, 'lambda_l2': 0.03092577215643299, 'learning_rate': 0.05046221199637873, 'max_depth': 100, 'n_estimators': 30040, 'feature_fraction': 0.4442252050527111, 'bagging_fraction': 0.4221880344250521, 'bagging_freq': 3, 'num_leaves': 929, 'min_child_samples': 289, 'min_data_per_groups': 90}. Best is trial 41 with value: 0.5966480059306036.
# [I 2022-10-26 20:26:13,212] Trial 47 finished with value: 0.5884483448525488 and parameters: {'lambda_l1': 0.4530550407483871, 'lambda_l2': 0.025732603413088705, 'learning_rate': 0.2341383630881189, 'max_depth': 100, 'n_estimators': 15484, 'feature_fraction': 0.4303596098878172, 'bagging_fraction': 0.41045081672464645, 'bagging_freq': 2, 'num_leaves': 926, 'min_child_samples': 287, 'min_data_per_groups': 90}. Best is trial 41 with value: 0.5966480059306036.
# [I 2022-10-26 20:26:17,103] Trial 48 finished with value: 0.5936855821027149 and parameters: {'lambda_l1': 1.724351048103657, 'lambda_l2': 0.061274146170515485, 'learning_rate': 0.04392349029906205, 'max_depth': 100, 'n_estimators': 29333, 'feature_fraction': 0.44593561511633883, 'bagging_fraction': 0.44527870605082237, 'bagging_freq': 3, 'num_leaves': 903, 'min_child_samples': 298, 'min_data_per_groups': 97}. Best is trial 41 with value: 0.5966480059306036.
# [I 2022-10-26 20:26:21,484] Trial 49 finished with value: 0.5904938807111808 and parameters: {'lambda_l1': 1.1286289737586944e-08, 'lambda_l2': 0.02803022978816534, 'learning_rate': 0.052904866763505164, 'max_depth': 100, 'n_estimators': 67312, 'feature_fraction': 0.4052461822549188, 'bagging_fraction': 0.42800517430038765, 'bagging_freq': 3, 'num_leaves': 965, 'min_child_samples': 268, 'min_data_per_groups': 13}. Best is trial 41 with value: 0.5966480059306036.
# Study Best Value: 0.5966480059306036
# Study Best Params: {'lambda_l1': 0.005360547526748144, 'lambda_l2': 1.1110651532516205, 'learning_rate': 0.02491008620991838, 'max_depth': 20, 'n_estimators': 170190, 'feature_fraction': 0.5913968004295521, 'bagging_fraction': 0.5581590256707243, 'bagging_freq': 5, 'num_leaves': 848, 'min_child_samples': 273, 'min_data_per_groups': 83}
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 588 operations to synchronize with Neptune. Do not kill this process.
# All 588 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/cmunch1/nba-optuna/e/NBAOPT-2

# %% [markdown]
# ### LightGBM

# %%
# %%time

#initialize oof arrays including Shapley values 
train_oof = np.zeros((train.shape[0],))
train_oof_shap = np.zeros((train.shape[0],train.shape[1]+1))
#train_oof_shap_interact = np.zeros((train.shape[0],train.shape[1]+1,train.shape[1]+1))


# K-fold cross validation

kf = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=SEED)

for f, (train_ind, val_ind) in tqdm(enumerate(kf.split(train, target))):
    
    train_df, val_df = train.iloc[train_ind], train.iloc[val_ind]
    train_target, val_target = target[train_ind], target[val_ind]

    train_lgbdataset = lgb.Dataset(train_df, label=train_target, categorical_feature=category_columns)
    val_lgbdataset = lgb.Dataset(val_df, label=val_target, reference = train_lgbdataset, categorical_feature=category_columns)

    model =  lgb.train(lgb_params, 
                       train_lgbdataset,
                       valid_sets=val_lgbdataset,
                       #num_boost_round = NUM_BOOST_ROUND,
                       callbacks=[log_evaluation(LOG_EVALUATION),
                                  early_stopping(EARLY_STOPPING,verbose=False),
                                  neptune_callback],
                       #verbose_eval= VERBOSE_EVAL,
                      )

    temp_oof = model.predict(val_df)
    temp_oof_shap = model.predict(val_df, pred_contrib=True)
    #temp_oof_shap_interact = model.predict(val_df, pred_interactions=True)

    train_oof[val_ind] = temp_oof

    train_oof_shap[val_ind, :] = temp_oof_shap
    #train_oof_shap_interact[val_ind, :,:] = temp_oof_shap_interact
    
    #for accuracy score, prediction probabilities must be convert to binary scores (Win or Lose)
    #determine optimum threshold for conveting probablities using ROC curve
    #generally 0.5 works for balanced data
    #fpr = false positive rate, tpr = true postive rate
    fpr, tpr, thresholds = roc_curve(val_target,temp_oof)
    optimal_idx = np.argmax(tpr - fpr)
    optimal_threshold = thresholds[optimal_idx]
    temp_oof_binary = (temp_oof > optimal_threshold).astype(int)

    print(accuracy_score(val_target, temp_oof_binary), roc_auc_score(val_target, temp_oof))

    
# Out-of-Fold composite for train data

fpr, tpr, thresholds = roc_curve(target,train_oof)
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
train_oof_binary = (train_oof > optimal_threshold).astype(int)

#neptune.ai logging    
run["train_model_summary"] = create_booster_summary(
    booster=model,
    log_trees=True,
    list_trees=[0, 1,],
    log_confusion_matrix=True,
    y_pred=train_oof_binary,
    y_true=target,
)
run["train/accuracy"] = acc_score = accuracy_score(target, train_oof_binary)
run["train/AUC"] = auc_score = roc_auc_score(target, train_oof)
run["train/optimal_threshold"] = optimal_threshold
                                 
print()
print("OOF CV Scores:")
print()
print("Accuracy Score:", acc_score)
print("AUC Score:", auc_score)
print("Optimal Threshold:", optimal_threshold)
# Out:
# 0it [00:00, ?it/s]
# [LightGBM] [Warning] Unknown parameter: min_data_per_groups
# [100]	valid_0's auc: 0.625867
# [200]	valid_0's auc: 0.624351
# 1it [00:06,  6.07s/it]
# 0.5848156182212582 0.6275048290970422
# [LightGBM] [Warning] Unknown parameter: min_data_per_groups
# [100]	valid_0's auc: 0.653574
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 0.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 1.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 2.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 3.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 4.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 5.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 6.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 7.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 8.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 9.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 10.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 11.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 12.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 13.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 14.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 15.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 16.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 17.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 18.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 19.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 20.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 21.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 22.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 23.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 24.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 25.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 26.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 27.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 28.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 29.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 30.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 31.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 32.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 33.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 34.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 35.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 36.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 37.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 38.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 39.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 40.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 41.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 42.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 43.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 44.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 45.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 46.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 47.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 48.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 49.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 50.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 51.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 52.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 53.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 54.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 55.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 56.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 57.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 58.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 59.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 60.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 61.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 62.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 63.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 64.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 65.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 66.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 67.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 68.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 69.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 70.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 71.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 72.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 73.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 74.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 75.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 76.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 77.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 78.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 79.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 80.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 81.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 82.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 83.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 84.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 85.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 86.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 87.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 88.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 89.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 90.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 91.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 92.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 93.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 94.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 95.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 96.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 97.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 98.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 99.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 100.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 101.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 102.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 103.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 104.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 105.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 106.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 107.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 108.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 109.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 110.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 111.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 112.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 113.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 114.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 115.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 116.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 117.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 118.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 119.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 120.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 121.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 122.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 123.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 124.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 125.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 126.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 127.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 128.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 129.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 130.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 131.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 132.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 133.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 134.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 135.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 136.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 137.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 138.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 139.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 140.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 141.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 142.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 143.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 144.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 145.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 146.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 147.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 148.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 149.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 150.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 151.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 152.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 153.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 154.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 155.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 156.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 157.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 158.0
# [200]	valid_0's auc: 0.648557
# 2it [00:08,  4.10s/it]
# 0.6227765726681128 0.655422068637215
# [LightGBM] [Warning] Unknown parameter: min_data_per_groups
# [100]	valid_0's auc: 0.64286
# [200]	valid_0's auc: 0.641841
# 3it [00:12,  3.73s/it]
# 0.6196571924495552 0.6453704505541915
# [LightGBM] [Warning] Unknown parameter: min_data_per_groups
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 159.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 160.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 161.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 162.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 163.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 164.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 165.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 166.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 167.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 168.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 169.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 170.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 171.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 172.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 173.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 174.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 175.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 176.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 177.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 178.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 179.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 180.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 181.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 182.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 183.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 184.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 185.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 186.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 187.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 188.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 189.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 190.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 191.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 192.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 193.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 194.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 195.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 196.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 197.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 198.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 199.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 200.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 201.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 202.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 203.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 204.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 205.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 206.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 207.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 208.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 209.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 210.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 211.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 212.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 213.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 214.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 215.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 216.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 217.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 218.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 219.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 220.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 221.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 222.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 223.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 224.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 0.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 1.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 2.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 3.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 4.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 5.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 6.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 7.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 8.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 9.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 10.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 11.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 12.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 13.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 14.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 15.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 16.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 17.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 18.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 19.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 20.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 21.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 22.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 23.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 24.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 25.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 26.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 27.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 28.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 29.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 30.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 31.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 32.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 33.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 34.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 35.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 36.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 37.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 38.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 39.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 40.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 41.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 42.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 43.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 44.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 45.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 46.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 47.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 48.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 49.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 50.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 51.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 52.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 53.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 54.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 55.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 56.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 57.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 58.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 59.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 60.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 61.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 62.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 63.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 64.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 65.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 66.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 67.0
# ...
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 183.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 184.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 185.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 186.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 187.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 188.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 189.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 190.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 191.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 192.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 193.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 194.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 195.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 196.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 197.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 198.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 199.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 200.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 201.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 202.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 203.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 204.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 205.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 206.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 207.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 208.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 209.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 210.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 211.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 212.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 213.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 214.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 215.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 216.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 217.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 218.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 219.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 220.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 221.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 222.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 223.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 224.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 225.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 226.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 227.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 228.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 229.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 230.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 231.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 232.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 233.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 234.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 235.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 236.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 237.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 238.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 239.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 240.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 241.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 242.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 243.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 244.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 245.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 246.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 247.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 248.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 249.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 250.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 251.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 252.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 253.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 254.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 255.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 256.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 257.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 258.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 259.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 260.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 261.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 262.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 263.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 264.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 265.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 266.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 267.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 268.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 269.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 270.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 271.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 272.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 273.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 274.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 275.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 276.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 277.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 278.0
# Error occurred during asynchronous operation processing: X-coordinates (step) must be strictly increasing for series attribute: valid_0/auc. Invalid point: 279.0
# OOF CV Scores:
#
# Accuracy Score: 0.6127478630624377
# AUC Score: 0.6434935385009727
# Optimal Threshold: 0.5891088007645633
# CPU times: user 1min 44s, sys: 1.36 s, total: 1min 45s
# Wall time: 19.4 s

# %% [markdown]
# **OOF Confusion Matrix**

# %%
cm = confusion_matrix(target, train_oof_binary)
print(cm)
fig = plot_confusion_matrix(cm,['win','lose'])
run["train/confusion_matrix"].upload(fig)
# Out:
# [[5296 4088]
#  [4837 8826]]

# %% [markdown]
# **OOF Classification report**

# %%
run["train/classification_report"] = classification_report(target, train_oof_binary)
print(classification_report(target, train_oof_binary))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.56      0.54      9384
#          1.0       0.68      0.65      0.66     13663
#
#     accuracy                           0.61     23047
#    macro avg       0.60      0.61      0.60     23047
# weighted avg       0.62      0.61      0.61     23047

# %% [markdown]
# **Train Feature Importance via Split - the number of times a feature is used in the model**

# %% [raw]
# max_features = 25
# max_title = 'Top ' + str(max_features) + ' Feature importance - Splits'
# fig, ax = plt.subplots(1,1,figsize=(10,10))
# lgb.plot_importance(model, importance_type='split', max_num_features=max_features, title=max_title ,ax=ax)
# run["train/feature_importance_split"].upload(fig)

# %% [markdown]
# **Train Feature Importance via Gain - the average gain of splits which use the feature**

# %%
max_features = 25
max_title = 'Top ' + str(max_features) + ' Feature importance - Gain'
fig, ax = plt.subplots(1,1,figsize=(10,10))
lgb.plot_importance(model, importance_type='gain', max_num_features=max_features, title=max_title ,ax=ax)
run["train/feature_importance_gain"].upload(fig)

# %% [markdown]
# **OOF Feature Importance via Shapley values**

# %%
# summarize the effects of all the features
fig, ax = plt.subplots(1,1,figsize=(10,10))
shap.summary_plot(train_oof_shap[:,:-1], train)
run["train/shapley_summary"].upload(fig)

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10))
shap.summary_plot(train_oof_shap[:,:-1], train[use_columns], plot_type="bar")
run["train/shapley_summary_bar"].upload(fig)

# %% [markdown]
# ### Test Data Evaluation

# %%
test_preds = model.predict(test)
test_preds_shap = model.predict(test, pred_contrib=True)

fpr, tpr, thresholds = roc_curve(test_target, test_preds)
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
test_preds_binary = (test_preds > optimal_threshold).astype(int)

run["test_model_summary"] = create_booster_summary(
    booster=model,
    log_trees=True,
    list_trees=[0, 1,],
    log_confusion_matrix=True,
    y_pred=test_preds_binary,
    y_true=test_target,
)
run["test/accuracy"] = acc_score = accuracy_score(test_target, test_preds_binary)
run["test/AUC"] = auc_score = roc_auc_score(test_target, test_preds)
run["test/optimal_threshold"] = optimal_threshold

print()
print("Accuracy Score:", acc_score)
print("AUC Score:", auc_score)
print("Optimal Threshold:", optimal_threshold)
# Out:
# Accuracy Score: 0.5881188118811881
# AUC Score: 0.6192103174603175
# Optimal Threshold: 0.6225963220177755

# %% [markdown]
# **Test Confusion Matrix**

# %%
cm = confusion_matrix(test_target, test_preds_binary)
print(cm)
fig = plot_confusion_matrix(cm,['win','lose'])
run["test/confusion_matrix"].upload(fig)
# Out:
# [[292 158]
#  [258 302]]

# %% [markdown]
# **Test Classification report**

# %%
run["test/classification_report"] = classification_report(test_target, test_preds_binary)
print(classification_report(test_target, test_preds_binary))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.65      0.58       450
#          1.0       0.66      0.54      0.59       560
#
#     accuracy                           0.59      1010
#    macro avg       0.59      0.59      0.59      1010
# weighted avg       0.60      0.59      0.59      1010

# %% [markdown]
# **Test Feature Importance via Shapley values**
#
# For comparison to cross-validation OOF Shapley values to ensure that the model is working in similar manner on the test data as train data

# %%
# summarize the effects of all the features
fig, ax = plt.subplots(1,1,figsize=(10,10))
shap.summary_plot(test_preds_shap[:,:-1], test)
run["test/shapley_summary"].upload(fig)

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10))
shap.summary_plot(test_preds_shap[:,:-1], test[use_columns], plot_type="bar")
run["test/shapley_summary_bar"].upload(fig)

# %% [markdown]
# **End experiment tracking**

# %%
#end experiment tracking
run.stop()
# Out:
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 35 operations to synchronize with Neptune. Do not kill this process.
# All 35 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/cmunch1/nba-prediction/e/XGB-37
