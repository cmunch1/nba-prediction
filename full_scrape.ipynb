# %%
import os

import pandas as pd
import numpy as np


from datetime import datetime, timedelta
from pytz import timezone

from src.webscraping import (
    activate_web_driver,
    scrape_to_dataframe,
    convert_columns,
    combine_home_visitor,  
    get_todays_matchups,
)

from src.data_processing import (
    process_games,
    add_TARGET,
)

from src.feature_engineering import (
    process_features,
)


from pathlib import Path  #for Windows/Linux compatibility
DATAPATH = Path(r'data')

# %% [markdown]
# **Activate Webdriver**

# %%
# initiate a webdriver in selenium 
# since website data is dynamically generated

driver = activate_web_driver('chromium')

# %% [markdown]
# **Scrape Advanced Boxscore data**

# %%
season_range = range(2002, 2023)
stat_types = ['traditional', 'advanced', 'four-factors', 'misc', 'scoring']




for stat_type in stat_types:
    print(f"Starting stat type {stat_type}")
    df_seasons = pd.DataFrame()
    
   
    for season in season_range:
        print(f"Starting season {season}")
        SEASON = f"{season}-{(season-2000+1):02}"
        df = scrape_to_dataframe(driver, SEASON, stat_type=stat_type)
        #concat to existing dataframe
        df_seasons = pd.concat([df_seasons, df], axis=0)
        #print(df)

    #save to csv
    df_seasons.to_csv(DATAPATH / f"{stat_type}_seasons.csv", index=False)
# Out:
# Starting stat type misc
# Starting season 2002
# https://www.nba.com/stats/teams/boxscores-misc?Season=2002-03
# all pages loaded
# Starting season 2003
# https://www.nba.com/stats/teams/boxscores-misc?Season=2003-04
# all pages loaded
# Starting season 2004
# https://www.nba.com/stats/teams/boxscores-misc?Season=2004-05
# all pages loaded
# Starting season 2005
# https://www.nba.com/stats/teams/boxscores-misc?Season=2005-06
# all pages loaded
# Starting season 2006
# https://www.nba.com/stats/teams/boxscores-misc?Season=2006-07
# all pages loaded
# Starting season 2007
# https://www.nba.com/stats/teams/boxscores-misc?Season=2007-08
# all pages loaded
# Starting season 2008
# https://www.nba.com/stats/teams/boxscores-misc?Season=2008-09
# all pages loaded
# Starting season 2009
# https://www.nba.com/stats/teams/boxscores-misc?Season=2009-10
# all pages loaded
# Starting season 2010
# https://www.nba.com/stats/teams/boxscores-misc?Season=2010-11
# all pages loaded
# Starting season 2011
# https://www.nba.com/stats/teams/boxscores-misc?Season=2011-12
# all pages loaded
# Starting season 2012
# https://www.nba.com/stats/teams/boxscores-misc?Season=2012-13
# all pages loaded
# Starting season 2013
# https://www.nba.com/stats/teams/boxscores-misc?Season=2013-14
# all pages loaded
# Starting season 2014
# https://www.nba.com/stats/teams/boxscores-misc?Season=2014-15
# all pages loaded
# Starting season 2015
# https://www.nba.com/stats/teams/boxscores-misc?Season=2015-16
# all pages loaded
# Starting season 2016
# https://www.nba.com/stats/teams/boxscores-misc?Season=2016-17
# all pages loaded
# Starting season 2017
# https://www.nba.com/stats/teams/boxscores-misc?Season=2017-18
# all pages loaded
# Starting season 2018
# https://www.nba.com/stats/teams/boxscores-misc?Season=2018-19
# all pages loaded
# Starting season 2019
# https://www.nba.com/stats/teams/boxscores-misc?Season=2019-20
# all pages loaded
# Starting season 2020
# https://www.nba.com/stats/teams/boxscores-misc?Season=2020-21
# all pages loaded
# Starting season 2021
# https://www.nba.com/stats/teams/boxscores-misc?Season=2021-22
# all pages loaded
# Starting season 2022
# https://www.nba.com/stats/teams/boxscores-misc?Season=2022-23
# all pages loaded
# Starting stat type scoring
# Starting season 2002
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2002-03
# all pages loaded
# Starting season 2003
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2003-04
# all pages loaded
# Starting season 2004
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2004-05
# all pages loaded
# Starting season 2005
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2005-06
# all pages loaded
# Starting season 2006
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2006-07
# all pages loaded
# Starting season 2007
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2007-08
# all pages loaded
# Starting season 2008
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2008-09
# all pages loaded
# Starting season 2009
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2009-10
# all pages loaded
# Starting season 2010
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2010-11
# all pages loaded
# Starting season 2011
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2011-12
# all pages loaded
# Starting season 2012
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2012-13
# all pages loaded
# Starting season 2013
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2013-14
# all pages loaded
# Starting season 2014
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2014-15
# all pages loaded
# Starting season 2015
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2015-16
# all pages loaded
# Starting season 2016
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2016-17
# all pages loaded
# Starting season 2017
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2017-18
# all pages loaded
# Starting season 2018
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2018-19
# all pages loaded
# Starting season 2019
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2019-20
# all pages loaded
# Starting season 2020
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2020-21
# all pages loaded
# Starting season 2021
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2021-22
# all pages loaded
# Starting season 2022
# https://www.nba.com/stats/teams/boxscores-scoring?Season=2022-23
# all pages loaded

# %% [markdown]
# **Close Webdriver**

# %%
driver.close()
